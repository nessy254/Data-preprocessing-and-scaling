# %% [markdown]
# DATA PREPROCESSING

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("ebola_2014_2016_clean.csv")
data=df.drop(['Date'], axis =1)
data.head()
# Out:
#         Country  Cumulative no. of confirmed, probable and suspected cases  \
# 0        Guinea                                              648.0
# 1       Nigeria                                               19.0
# 2  Sierra Leone                                             1026.0
# 3       Liberia                                             1378.0
# 4  Sierra Leone                                             1261.0
#
#    Cumulative no. of confirmed, probable and suspected deaths
# 0                                              430.0
# 1                                                7.0
# 2                                              422.0
# 3                                              694.0
# 4                                              491.0

# %%
#checking for null values
data.isna().sum()
# Out:
# Country                                                       0
# Cumulative no. of confirmed, probable and suspected cases     8
# Cumulative no. of confirmed, probable and suspected deaths    0
# dtype: int64

# %%
#checking for duplicates
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2480     True
# 2481     True
# 2482    False
# 2483     True
# 2484     True
# Length: 2485, dtype: bool

# %%
#Extracting independent variable
x=data.iloc[:,:-1].values
x
# Out:
# array([['Guinea', 648.0],
#        ['Nigeria', 19.0],
#        ['Sierra Leone', 1026.0],
#        ...,
#        ['Liberia', 5.0],
#        ['Nigeria', 20.0],
#        ['United States of America', 4.0]], dtype=object)

# %%
#Extracting dependent variable
y=data.iloc[:,1].values
y
# Out:
# array([ 648.,   19., 1026., ...,    5.,   20.,    4.])

# %%
#filling the missing values wuth the mean
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean') 
imputer = imputer.fit(data[['Cumulative no. of confirmed, probable and suspected cases']])
data[['Cumulative no. of confirmed, probable and suspected cases']]= imputer.transform(df[['Cumulative no. of confirmed, probable and suspected cases']])
data.head()
# Out:
#         Country  Cumulative no. of confirmed, probable and suspected cases  \
# 0        Guinea                                              648.0
# 1       Nigeria                                               19.0
# 2  Sierra Leone                                             1026.0
# 3       Liberia                                             1378.0
# 4  Sierra Leone                                             1261.0
#
#    Cumulative no. of confirmed, probable and suspected deaths
# 0                                              430.0
# 1                                                7.0
# 2                                              422.0
# 3                                              694.0
# 4                                              491.0

# %%
#no null values 
data.isna().sum()
# Out:
# Country                                                       0
# Cumulative no. of confirmed, probable and suspected cases     0
# Cumulative no. of confirmed, probable and suspected deaths    0
# dtype: int64

# %%
# encoding the string variable,country
from sklearn.preprocessing import LabelEncoder  
label_encoder_x= LabelEncoder()  
x[:, 0]= label_encoder_x.fit_transform(x[:, 0])
x
# Out:
# array([[ 0.        , -0.43054271],
#        [ 4.        , -0.57265028],
#        [ 6.        , -0.34514261],
#        ...,
#        [ 2.        , -0.57581325],
#        [ 4.        , -0.57242435],
#        [ 9.        , -0.57603917]])

# %%
labelencoder_y= LabelEncoder()  
y= labelencoder_y.fit_transform(y)
y
# Out:
# array([15, 10, 23, ...,  5, 11,  4], dtype=int64)

# %%
#feature scaling
from sklearn.preprocessing import StandardScaler

# %%
#feature scaling
scaler= StandardScaler()
x= scaler.fit_transform(x)
st_x
print(x)
# Out:
# [[-1.5892021  -0.43054271]
#  [-0.16838281 -0.57265028]
#  [ 0.54202684 -0.34514261]
#  ...
#  [-0.87879246 -0.57581325]
#  [-0.16838281 -0.57242435]
#  [ 1.60764131 -0.57603917]]

# %%
#splitting the data into train and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state=0)

# %%
#x_train values
x_train= scaler.transform(x_train)
x_train
# Out:
# array([[-2.08530658,  2.35219013],
#        [-2.08530658,  2.3951161 ],
#        [-2.26457201,  1.83278582],
#        ...,
#        [-1.99567386, -0.57671695],
#        [-2.04049022, -0.57671695],
#        [-1.99567386, -0.57671695]])

# %%
#x_test values
x_test= scaler.transform(x_test)
x_test
# Out:
# array([[-2.36175103, -0.57242435],
#        [-2.29807509, -0.57671695],
#        [-2.2821561 , -0.57603917],
#        [-2.31399407, -0.57671695],
#        [-2.42542698,  0.26915069],
#        [-2.40950799, -0.57671695],
#        [-2.32991306,  2.61358672],
#        [-2.40950799, -0.57671695],
#        [-2.42542698,  0.27976922],
#        [-2.2821561 , -0.57603917],
#        [-2.34583205, -0.57671695],
#        [-2.42542698, -0.34920928],
#        [-2.29807509, -0.57671695],
#        [-2.2821561 , -0.57603917],
#        [-2.36175103, -0.57242435],
#        [-2.32991306,  2.40731611],
#        [-2.2821561 , -0.57603917],
#        [-2.34583205, -0.57671695],
#        [-2.2821561 , -0.57603917],
#        [-2.29807509, -0.57671695],
#        [-2.39358901,  1.83278582],
#        [-2.39358901,  1.83278582],
#        [-2.37767002, -0.57513547],
#        [-2.34583205, -0.57671695],
#        [-2.34583205, -0.57671695],
#        [-2.2821561 , -0.57603917],
#        [-2.39358901,  1.83278582],
# ...
